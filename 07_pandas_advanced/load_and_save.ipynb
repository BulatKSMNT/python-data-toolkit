# %%
import pandas as pd
df = pd.read_csv("../data/feed-views.log", sep="\t", skiprows=lambda x: x == 0 or x == 1, engine='python', skipfooter=2, names=['datetime', 'user'], header=None, index_col ='datetime')
df.index.name = 'date_time'  
df.columns = [""]     
df.columns.name = 'user'

# %%
print(df.head(4))
# Out:
# user
# date_time
# 2020-04-17 12:27:30.646665   artem
# 2020-04-17 12:35:44.884757   artem
# 2020-04-17 12:35:52.735016   artem
# 2020-04-17 12:36:21.401412  oksana

# %%
print(df.tail(4))
# Out:
# user
# date_time
# 2020-05-21 17:49:36.429237      maxim
# 2020-05-21 18:45:20.441142  valentina
# 2020-05-21 23:03:06.457819      maxim
# 2020-05-21 23:23:49.995349      pavel

# %%
df.to_csv("../data/feed-views-semicolon.log", sep = ";")
